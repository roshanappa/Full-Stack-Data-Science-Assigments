# %% [markdown]
# ![image.png](attachment:20205c4f-6bef-4281-90c9-41f5ceef3734.png)

# %%
string = "This is my assignment"
string[:1]='I'

# %% [markdown]
# By above we can say it will not violate Python's string Immutatbility.

# %% [markdown]
# ![image.png](attachment:c1a68a6f-ba81-42b9-ae00-f2897a02eded.png)

# %%
string +=string

# %%
print(string)

# %% [markdown]
# - Another string is getting added with the help concatenation operation but does not means that they have got the index postion of privious string.It has created the new space with new index position.
# - Here,in this case privious string consisting the same position for each alpahbate.
# - So,from that we can say string is still immutable.

# %% [markdown]
# ![image.png](attachment:6f506957-89f2-458c-8293-80d96f562acd.png)

# %% [markdown]
# Indexing means referring to an element of an iterable by its position within the iterable. Each of a string’s characters corresponds to an index number and each character can be accessed using their index number.
#
# We can access characters in a String in Two ways :
#
# - Accessing Characters by Positive Index Number
# - Accessing Characters by Negative Index Number

# %% [markdown]
# ![image.png](attachment:6cfd024b-55ae-4598-a930-aa5de9e93ae7.png)

# %% [markdown]
# - In the indexing we have provided the reference number from left to right from 0 to till then end number in positive number for each attribute inside ieratble object.
# - Similarly for right to left is going to index from -1 to to final number in negetive index.

# %% [markdown]
# - With the help of the indexing we can easily retrieve the data from that  interable object and these process called as Slicing.

# %% [markdown]
# ![image.png](attachment:836b529d-52b1-4dbe-90e0-db09514244c8.png)

# %%
string1 = 'Roshan'
type(string1[0])

# %%
string1 = 'Roshan'
type(string1[0:3])

# %% [markdown]
# ![image.png](attachment:29f30466-02ef-43ae-8589-ee9c1d42dd6d.png)

# %% [markdown]
# - With the help number of charecter we can make the string.

# %%
type(chr) #it does have facility as like as we have in string It is an method

# %%
type(str) #class

# %% [markdown]
# ![image.png](attachment:d8a79cce-7ec1-48c8-b842-d5c947a6ad89.png)

# %%
string + string #one operator

# %%
string*2

# %%
 strings = ['do', 're', 'mi']
','.join(strings)

# %% [markdown]
# ![image.png](attachment:7e93fee3-686e-4cfc-83c0-55f1e811c2d9.png)

# %% [markdown]
# - It help to reduce our time.
# - Makes productive work.
# - Got Prevention before taking an unnessary action.

# %% [markdown]
# ![image.png](attachment:227d6256-2908-405b-b938-1faa629a76ed.png)

# %% [markdown]
# There are some operations like below wayt

# %%
a =10
b =90

a>b

# %%
a<b

# %% [markdown]
# - Whichever the comparision operator we have been using can gives us True and False statement.
# - If and else statement also provide True and False result.

# %%
'i' in "Roshan"

# %%
'R' in "Roshan"

# %%
type(20) is int

# %%
type(20) is float
