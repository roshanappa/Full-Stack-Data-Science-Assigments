# %% [markdown]
# ![image.png](attachment:4cd5d8b6-1d9a-49bd-b176-3fa62de9cb92.png)

# %% [markdown]
# - Create wire-frame diagram
# - Create HLD and LLD
# - Collect Data
# - Prepare the data
# - Choose the model
# - Train your machine model
# -  Evaluation
# - Parameter Tuning
# - Prediction or Inference

# %% [markdown]
# ![image.png](attachment:e47b6a13-be7f-40cc-8a9c-afe99a3a22b5.png)

# %% [markdown]
# - Continous data  :- Stock Prices,age,humidity,air quality index,etc.
# - Categorical data :- Gender,state,names,pincode,etc.
# - Boolean data :True or False

# %% [markdown]
# ![image.png](attachment:34572891-8e96-4d9c-ac0c-772d721007ff.png)

# %% [markdown]
# **Numerical Vs. Categorical**
#
# - Numerical having data in integer or float with continous data distribution.
# - Categorical can be avaliable in the form of integer and string but data distribution will descrete form.
#
# **Feature Selection Vs. Dimesionality Reduction**
#
# - By using the hypothesis of statstical technique we can determine the which features are good for prediction for the target variable.
# - Dimesionality reduction technique is going to reduce the dimensionality based of variance avaliable at the different arthogonal plan.

# %% [markdown]
# ![image.png](attachment:d7dfefb7-6433-4719-8834-3e47e23b78bd.png)

# %% [markdown]
# **The Histogram**
# - Histogram is the graph which shows how the categorical distribution is happening.
# - It takes bin of the categories and then takes it count.
# - Accordingly,it creates the distributed graph called as histogram.
#
# **Use a Scatter Plot**
# - Scatterplot is used to get the distribution of numerical values in respect of other numrical values so that we can determine how well they are correlated to each other.

# %% [markdown]
# ![image.png](attachment:75ebc2ba-27f1-496d-9b0b-c1c50b800b78.png)

# %% [markdown]
# - Inside the data sharing agreement,we need to cross check our data is fullfill our requirement or not for the prediction.
# - So,for that we already have to be sure about the data from the client.
# - qualitative data is getting avaliable in the form of continous numrical format.
# - Quantative data is getting avaliable in the form of categorical format.

# %% [markdown]
# ![image.png](attachment:c27e870a-095c-4427-9d4f-563a4bb6cce7.png)

# %% [markdown]
# - Right Skewed Histogram
# - Left Skewed Histogram
# - Bell Shaped
# - Uniform
# - Bimodal
# - Multi-modal
# - Random
#
# Bins are not but the set of groups of the categories which will gonna indicate the count of each each set of category in the histogram.

# %% [markdown]
# ![image.png](attachment:1023e3d0-1be8-4e91-bf98-6f13a5afb4c3.png)

# %% [markdown]
# - If we have any outliers inside the data that time model can give us biased outcome.
# - So if we dont want it then we we have to do the outlier treatment in that we are going to remove the outliers.
# - For that we have some methods
# - IQR
# - Z-Score
# - Threshold based outliers treatment.

# %% [markdown]
# ![image.png](attachment:98b772f4-2853-429d-92ab-a5189ce6ef0c.png)

# %% [markdown]
# - Three of the many ways to measure central tendency are the mean, median and mode.
# - Sometimes mean getting vary too much from medium in certain datasets just because of outliers avaliability inside the data.

# %% [markdown]
# ![image.png](attachment:c9fc73fd-0ca7-47f1-85c0-17370047b75c.png)

# %% [markdown]
# - By using scatterplot we will get the distribution in such way there we can understand the x and y cordinate values relationship.
# - As the plot moving foreward in the positive direction then we can x and y values positive correlated to each other or wise versa.
# - By using the scatterplot we can understand the dense part of data points and sparse data points so whichever the data points are far away are called as outliers.

# %% [markdown]
# ![image.png](attachment:3ba42368-7662-46b9-a98c-dcbddca64891.png)

# %% [markdown]
# - Cross tabulation is a method to quantitatively analyze the relationship between multiple variables. Also known as contingency tables or cross tabs, cross tabulation groups variables to understand the correlation between different variables. It also shows how correlations change from one variable grouping to another
