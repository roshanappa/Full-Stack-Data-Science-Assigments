# %% [markdown]
# ![image.png](attachment:7ef411f3-19f4-4281-91fd-b79b18068a25.png)

# %% [markdown]
# In machine learning, features are individual independent variables that act like a input in your system. Actually, while making the predictions, models use such features to make the predictions. And using the feature engineering process, new features can also be obtained from old features in machine learning.
# To understand in more simple way, lets take an example, where you can consider one column of your data set to be one feature which is also know as “variables or attributes” and the more number of features are known as dimensions. And depending on what you are trying to analyze the features you include in your dataset can vary widely.

# %% [markdown]
# ![image.png](attachment:3e41a6a2-90da-44b2-a4db-013ba42e776f.png)

# %% [markdown]
# Feature construction involves transforming a given set of input features to generate a new set of more powerful features which can then used for prediction. Engineering a good feature space is a prerequisite for achieving high performance in any machine learning task.

# %% [markdown]
# ![image.png](attachment:3c372e5c-2f0d-4aef-adc9-36a38129f6f5.png)

# %% [markdown]
# - Nominal variables are the variables which does not show any effective order for the target variable.These can name the person,city,pincode etc.
# - These variables can be encoded with the help of OneHotEncoding,`pd.get_dummies with drop_first =True`

# %% [markdown]
# ![image.png](attachment:83515a22-d3cb-4bed-bc2d-5d338fbdaf40.png)

# %% [markdown]
# - Using `.map()` function.

# %% [markdown]
# ![image.png](attachment:a596092d-b1bb-4366-9073-e342ec78ce2b.png)

# %% [markdown]
# -In wrapper methods, the feature selection process is based on a specific machine learning algorithm that we are trying to fit on a given dataset. It follows a greedy search approach by evaluating all the possible combinations of features against the evaluation criterion.

# %% [markdown]
# ![image.png](attachment:1ae8285b-6f1a-4fea-85d5-db88a69a35c3.png)

# %% [markdown]
# ![image.png](attachment:c7aeca4e-dfa7-4030-8903-c43185e98a42.png)

# %% [markdown]
# - Whenever we do the feature engineering on the data in the respect of Target variable such as ANNOVA Test,Chi2_Test.
# - That time if any feature does not have good Annova and cHI2_TEST sCORE that feature called as irrelevant feature.
# - Althogh there are methods also avalible like Correlation Score.etc.
# - Wrapping methods,Filter method,Mutual information,and so on.

# %% [markdown]
# ![image.png](attachment:55083690-dbe7-4afb-994f-5df170921fd2.png)

# %% [markdown]
# - During data integration in data mining, various data stores are used. This can lead to the problem of redundancy in data. An attribute (column or feature of data set) is called redundant if it can be derived from any other attribute or set of attributes. Inconsistencies in attribute or dimension naming can also lead to the redundancies in data set.
# - Correlation Technique
# - Chi2_test

# %% [markdown]
# ![image.png](attachment:1150ec56-7956-480c-a36b-8788c9954733.png)

# %% [markdown]
# The distance measurements used to determine feature similarity are as given below
#
# - Eucleadian Distance
# - Manhatan Distance
# - Minkowski Distance
# - Hamming Distance

# %% [markdown]
# ![image.png](attachment:d297435e-d5b7-4cf6-86db-82431eea57ee.png)

# %% [markdown]
# - Euclidean Distance :- It is the diagonal distance between two data points in feature space.It based on the principle of pythagoras theorem.
# - Manhatan Distance  :- It is distance that is going to be measure in greedy approach.It means there is fix paths or organized to calculate the distance between two data points in feature Space.

# %% [markdown]
# ![image.png](attachment:658a3875-708b-4e55-a26b-1f8474866c0e.png)

# %% [markdown]
# ![image.png](attachment:836f9916-6101-4c57-9105-a37fec9dedcc.png)

# %% [markdown]
# - Feature Transformation :- Feature Transformation is nothing but the feature are getting change according to our requirements so that we can acheive the disirable accuracy from the avliable model.Like Scalling,Normalizing,FeatureEncoding,Removing outliers,Filling the null values,Understand the distribution and remove the duplicate columnsor rows.
# - Feature Selection :- Before going to proceed for training the algorithm we have to check we do have effective feature in feature space or not so that at end we will good accuaracy.
# - In the feature selection technique we can understand which feature is highly important for the target variable and accordingly select the features at the end.
# - It help us to remove redudant features and trying optimize the training time of algorithm as well.

# %% [markdown]
# ![image.png](attachment:9fd3def0-6f00-4c34-90f5-c9ece8a00984.png)

# %% [markdown]
# - SVD(Singular Value Decomposition)
# - Singular value decomposition (SVD) is a matrix factorization method that generalizes the eigendecomposition of a square matrix (n x n) to any matrix (n x m).
# - SVD is similar to Principal Component Analysis (PCA), but more general. PCA assumes that input square matrix, SVD doesn’t have this assumption. General formula of SVD is:
# - `M=UΣVᵗ`, where:
# - `M`-is original matrix we want to decompose
# - `U`-is left singular matrix (columns are left singular vectors). U columns contain eigenvectors of matrix MMᵗ
# - `Σ`-is a diagonal matrix containing singular (eigen)values
# - `V`-is right singular matrix (columns are right singular vectors). V columns contain eigenvectors of matrix MᵗM

# %% [markdown]
# ![image.png](attachment:462d6aab-dcbf-4fa8-b701-9803a11095fd.png)

# %% [markdown]
# -https://towardsdatascience.com/simple-svd-algorithms-13291ad2eef2

# %% [markdown]
# - **Collecting The Feature Using Hybrid Approach**
# - Hybrid Machine Learning Approaches: A Method to Improve Expected Output of Semi-structured Sequential Data.We train and test the work on data that is outside either an Artificial Neural Network or a state-machine's normal capability with simplified music notation extracted from midi files.
# - The hybrid approach combines the best of rule-based and ML approaches with natural language processing, machine learning, and human input. Human expertise provides guidance for accurate analysis and machine learning helps that analysis scale with ease.
# - The hybrid approach of sentiment analysis exploits both statistical methods and knowledge-based methods for polarity detection. It inherits high accuracy from the machine learning (statistical methods) and stability from the lexicon-based approach
