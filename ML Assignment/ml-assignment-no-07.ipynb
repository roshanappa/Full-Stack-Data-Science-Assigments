# %% [markdown]
# ![image.png](attachment:d5c44a3c-9676-4044-a74c-7ad0e2cc5885.png)

# %% [markdown]
# - A target function, in machine learning, is a method for solving a problem that an AI algorithm parses its training data to find. Once an algorithm finds its target function, that function can be used to predict results (predictive analysis). The function can then be used to find output data related to inputs for real problems where, unlike training sets, outputs are not included.
#
# - The target function is essentially the formula that an algorithm feeds data to in order to calculate predictions. As in algebra, it is common when training AI to find the variable from the solution, working in reverse. `The function as defined by f is applied to the input (I) to produce the output (I), Therefore O= f(I).`
#
# - Analyzing the massive amounts of data related to its given problem, an AI derives understanding of previously unspecified rules by detecting consistencies in the data. The observations of inherent rules about how the studied subject operates inform the AI on how to process future data that does not include an output by applying this previously unknown function.

# %% [markdown]
# ![image.png](attachment:e46ac4de-4b35-4d10-8244-eb8df37a1cfe.png)

# %% [markdown]
# - Predictive modeling solutions are a form of data-mining technology that works by analyzing historical and current data and generating a model to help predict future outcomes. ... Predictive models analyze past performance to assess how likely a customer is to exhibit a specific behavior in the future.
# - In predictive modeling, data is collected, a statistical model is formulated, predictions are made, and the model is validated (or revised) as additional data becomes available. For example, risk models can be created to combine member information in complex ways with demographic and lifestyle information from external sources to improve underwriting accuracy. Predictive models analyze past performance to assess how likely a customer is to exhibit a specific behavior in the future. This category also encompasses models that seek out subtle data patterns to answer questions about customer performance, such as fraud detection models. Predictive models often perform calculations during live transactions—for example, to evaluate the risk or opportunity of a given customer or transaction to guide a decision. If health insurers could accurately predict secular trends (for example, utilization), premiums would be set appropriately, profit targets would be met with more consistency, and health insurers would be more competitive in the marketplace.

# %% [markdown]
# - The descriptive analysis uses mainly unsupervised learning approaches for summarizing, classifying, extracting rules to answer what happens was happened in the past. While Predictive analysis is about machine learning approaches for the aim forecasting future data based on past data.

# %% [markdown]
# ![image.png](attachment:2506906f-fe95-44e8-b720-7e062d89072f.png)

# %% [markdown]
# - Methods of assessing a classification model's efficiency.
#  - Consfusion metrix
#  - F-Score
#  - Classification report
#  - AUC-ROC Curve
#  - Cross Validation Score
#  - Feature Engineering
#  - Precision And Accuarcy Score.

# %% [markdown]
# ![image.png](attachment:db01e385-7085-40a3-a151-67b57223b29b.png)

# %% [markdown]
# - Underfitting model is nothing but the model which have got the lower accuarcy in training data as well as testing data.
# - In this condition we have high bias and low variance.
# - It means there are lot of error are getting while predicting data in testing data.
# - It happened when we have very less amount of data for training and testing too.

# %% [markdown]
# - Overfitting model is nothing but the moel which have very good accuracy while training the data and getting lesser accuarcy whiling testing the data.
# - It means algorithm having data wich high variance and due to this reason it took lot of learning but while testing it get confused and resulting the bad result at the end.
# - In this condition we have high variance and low bias.
# - It happend due to lot of training data avaliablity or we have can unwanted column avaliability inside the data.
# - and improper algorithm selection and improper feature engineering technique.

# %% [markdown]
# - When we have higher variance inside the data and lower bias that time model complexity will be high.
# - When we have lower variance inside the data and higher bias that time model complexity will be low.
# - In the both condition we are not able get the best result in terms of accuaracy.
# - So we need spot there I can get the best results for the algorthm.
# - That would be low bias and low variance with lesser complexity.
# - That is also called as Bias-Variance Trade Off.

# %% [markdown]
# ![image.png](attachment:44deac1b-a875-4c8f-8b19-329de91beeb4.png)

# %% [markdown]
# - Yes,It can be done with the help of some techniques
# - Feature Engineering technique like ANNOVA Test,Chi2_Test.
# - Feature Scalling MinMax_Scalling,StandardScaling,RoboustScaler
# - Outliers Treatment :- Means removing the outlier it is required.
# - Use Proper Imputation techniqes.
# - Remove Imbalacement inside the data.
# - Remove Dupplicate columns and rows.
# - Remove the Colinerity Trapp.

# %% [markdown]
# ![image.png](attachment:5b1c60fa-ec9a-4afe-b686-42bad9dc16e1.png)

# %% [markdown]
# - First upon the unsupervised machine learning is nothing but clusting data based on similarity inbetween them.
# - Accordingly,It is going to label.
# - Then,use PCA in order reduce the dimensioanality and Use T-SNE for the vizualization.
# - After that use Silhouette score in order to understand is our data is getting clustered in good manner or not.
# - Silhouette score is near to 1 means clustering is good.
# - Silhouette score is not near to 1 means clustering is bad.

# %% [markdown]
# ![image.png](attachment:6d454e5c-29bc-4d97-9f8d-6908e188001b.png)[](http://)

# %% [markdown]
# - It is possible to use the classification model on the numeric data if the target variable is in descrete distribution.
# - So that It could be measure in the fraction.
# - But If we tried to apply the regression on the categorical data.It wil consider that data as value and trying find out best find line and that Will not going to helpful for classification algorithm.
# - Regression is best for the continous data which have the smooth bell curve in the distribution,wherease classification is good to use for descrete random variable.

# %% [markdown]
# ![image.png](attachment:ae9dc041-759a-4e08-95f5-fbf5208e0bb1.png)

# %% [markdown]
# - Predictive modeling for the numerical value is linear regression modeling there we have an dependent variable and independent variable.
# - On the basis of regression model we are going to predict the future value but for that interally the best fit line has been created by the algorith which basically adjusted itself in such way so that error will be miniumum.
# - It meansure the euclidean distance from best fit line.
# - Whereas in categorical predictive modeling the value are getting classified based of the avaliable data pattern.
# - For the classification of any category we need to have look for probablity of occurance or probabality of getting that class selection.
# - It can be validate further with the help of confusion metrics and etc.

# %% [markdown]
# ![image.png](attachment:51773325-d5ac-4852-9a41-1c9c8d1cd2ab.png)

# %% [markdown]
# for the Kappa Score we will be considering
# - Cancereous finds that 10 of the patients have actual Cancerous.
# - Benign finds 40 of the patients have actual benign.
# - Error Rate :- `0.1`
# - Kappa_Value :- `0.667`
# - Sensetivity:- `0.689`
# - Precision:- `0.8333`
# - F_Score :- `0.754`

# %% [markdown]
# https://elentra.healthsci.queensu.ca/assets/modules/reproducibility/calculating_kappa.html

# %% [markdown]
# ![image.png](attachment:1cd648a2-2474-4e96-b1b7-851196443848.png)

# %% [markdown]
# - **The Process Of Holding Out**
#  - Hold-out is when you split up your dataset into a 'train' and 'test' set. The training set is what the model is trained on, and the test set is used to see how well that model performs on unseen data.
#  - Holdout Method is the simplest sort of method to evaluate a classifier. In this method, the data set (a collection of data items or examples) is separated into two sets, called the Training set and Test set. A classifier performs function of assigning data items in a given collection to a target category or class

# %% [markdown]
# - **Cross Validation By Tenfold**
#  - 10-fold cross validation would perform the fitting procedure a total of ten times, with each fit being performed on a training set consisting of 90% of the total training set selected at random, with the remaining 10% used as a hold out set for validation.

# %% [markdown]
# - **Adjusting The Parameters**
#  - The data analysis computer program must change the parameter values to achieve a minimum value for the weighted sum of the squared residuals (WSS).
#  - Parameters are key to machine learning algorithms. ... In this case, a parameter is a function argument that could have one of a range of values. In machine learning, the specific model you are using is the function and requires parameters in order to make a prediction on new data.

# %% [markdown]
# ![image.png](attachment:89f2bac1-967b-45b2-822f-c6267c591a54.png)

# %% [markdown]
# - **Purity Vs Silhouette Width**
#  - We sum the number of correct class labels in each cluster and divide it by the total number of data points. In general, purity increases as the number of clusters increases. For instance, if we have a model that groups each observation in a separate cluster, the purity becomes one.
#  - The Silhouette Index measure the distance between each data point, the centroid of the cluster it was assigned to and the closest centroid belonging to another cluster.For instance, the silhouette index is normalized and a value close to 1 is always good (for this index) whatever clustering you are trying to evaluate.

# %% [markdown]
# - **Bagging & Boosting**
#  - Bagging is nothing but the making best predictive model by using the n number decsion tree or any models at a time with the help of replacement sampling or booststapping.There are some algorithms are avaliable which are working parellely on the some data at the end it is going combine the result in maxvoting form or in average form for classification and regression format.
#  - It is going to make High variance and low bise to Low variance and low bias.

# %% [markdown]
# - Boosting is the technique where we are going to keep upgrating the model's weak learners parameters to the strong learner so that at the end we will get the desirable output with good accuarcy.
# - Here,in this case all paramters are getting upadated in each iteration and trying minimuize the gradient or errors.

# %% [markdown]
# - **Eager Learner Vs. Lazy Learner**
#  - A lazy learner delays abstracting from the data until it is asked to make a prediction while an eager learner abstracts away from the data during training and uses this abstraction to make predictions rather than directly compare queries with instances in the dataset.
