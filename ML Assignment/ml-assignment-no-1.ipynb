# %% [markdown]
# [](http://)

# %% [markdown]
# ![image.png](attachment:48a2d5e6-e8de-4e20-b0e8-a27b23274dbe.png)

# %% [markdown]
# - Machine Learning is nothing but the learning pattern from the avaliable data and create the model in order predict the target variable called as machine learning.
# - Machine learning useful to predict,clustering the data according the pattern inside the data.

# %% [markdown]
# ![image.png](attachment:f8368652-cfcf-4fdd-9f15-bb2c16fd9d27.png)

# %% [markdown]
# - In banking froud detection.
# - Stocks prediction
# - Customer Segmentation
# - Sales Prediction
# - Classification of any entity based on avaliable data.

# %% [markdown]
# ![image.png](attachment:5b8dc377-1ef1-47cd-8601-d259af1d5421.png)

# %% [markdown]
# - The labeled traing set is nothing but the data is going to train over the model in order to get learning or pattern finding from that data.
# - In the machine learning we have to take randomly 70% or 80% of data as training data because of learning purpose and then it is going help to make model predictive in nature.

# %% [markdown]
# ![image.png](attachment:02b7a2c8-e409-4d17-ad28-43eef9d2ebb1.png)

# %% [markdown]
# - Continous Motoring the KPI of contious data
# - Classification of the data according to the nature of the data.

# %% [markdown]
# ![image.png](attachment:e0403319-79f1-424b-af70-2206d8d7ac76.png)

# %% [markdown]
# - Customer segmentation based on customer expenditure.
# - Clustering the data based on the choices and similarity.

# %% [markdown]
# ![image.png](attachment:17153109-7151-4166-bc78-9342d6d4c18a.png)

# %% [markdown]
# - The best Machine Learning algorithm to allow a robot to walk in unknown terrain is Reinforced Learning, where the robot can learn from response of the terrain to optimize itself.

# %% [markdown]
# ![image.png](attachment:fef028a5-f97a-4423-bda8-5cfb4cec5f71.png)

# %% [markdown]
# - It will depends on the data
# - I can use clustering
# - I can use Clasification
# - K-means clustering,KNN algorithm for classification,RandomForestClassifer.

# %% [markdown]
# ![image.png](attachment:25a97c4f-ee5a-45e3-8192-4ebe031cfd4d.png)

# %% [markdown]
# - It is supervised machine learning problem statement.

# %% [markdown]
# ![image.png](attachment:9787785b-0445-413b-b450-006ab34e651e.png)

# %% [markdown]
# - Online learning system is nothing but countious integration and countious deployment.
# - Here we are getting data from the server and dupming that data inside the pipeline and making countious prediction with help of cloud system.

# %% [markdown]
# ![image.png](attachment:ab972299-fca2-4aad-be70-52171e0b6ca2.png)

# %% [markdown]
# - Out-of-core learning refers to a set of algorithms working with data that cannot fit into the memory of a single computer, but that can easily fit into some data storage such as a local hard disk or web repository.
# - Your available RAM, the core memory on your single machine, may indeed range from a few gigabytes (sometimes 2 GB, more commonly 4 GB, but we assume that you have 2 GB at maximum) up to 256 GB on large server machines. Large servers are like the ones you can get on cloud computing services such as Amazon Elastic Compute Cloud (EC2), whereas your storage capabilities can easily exceed terabytes of capacity using just an external drive (most likely about 1 TB but it can reach up to 4 TB).
# - The term out-of-core typically refers to processing data that is too large to fit into a computer’s main memory.So it is like core learning.
#
# - Typically, when a dataset fits neatly into a computer’s main memory, randomly accessing sections of data has a (relatively) small performance penalty.
#
# - When data must be stored in a medium like a large spinning hard drive or an external computer network, it becomes very expensive to randomly seek to an arbitrary section of data or to process the same data multiple times.
#
# - In such a case, an out-of-core algorithm would try to access all relevant data in one sequence.
#
# - However, modern computers have a deep memory hierarchy, and replacing random access with sequential access can increase performance even on datasets that fit within memory.

# %% [markdown]
# ![image.png](attachment:fc48ad83-4a48-41e8-bf7d-849ba9b08505.png)

# %% [markdown]
# - K-means Clustering.
# - KNN algorithm.
# - Linear Regression

# %% [markdown]
# ![image.png](attachment:0f16e4fd-759b-4c53-b33a-947773d3ad71.png)

# %% [markdown]
# - Model parameters are called as paramters that are going be constant while traing the model and there is not alternative for that.
# - for the any algorithm we have the hyper-parameters and these paramters having their alternative to use and these paramter can affect the model accuracy.
# - So according our convenience we have to choose the best optimized paramters inside the machine learning algorithm and these paramters called as hyper-parameters.

# %% [markdown]
# ![image.png](attachment:0eb1c5b7-1f64-47ea-8496-c9caf3b3bef7.png)

# %% [markdown]
# - First we look target variable avaliable or not and based on that select the model.
# - Use the best feature engineering technique for getting good accuaracy.
# - Use standardization and Normalization.
# - Use best hyperparameter Tunning with the help of GridSearchCV and RandomSearchCV.
# - Use Cross Validation technique to get consitency of the model.
# - Use statstical techniques and outliers treatments.

# %% [markdown]
# ![image.png](attachment:2fee6529-120c-4694-b399-5a5bd1cdd08f.png)

# %% [markdown]
# - Data is not feasible enough to give us best possible outcome or prediction.
# - Data not sufficient enough to give us good accuracy.
# - Model overfitting.
# - Unstructure data.
# - Accurate Data Collection

# %% [markdown]
# ![image.png](attachment:bc03abe9-b6a6-4aa5-a38a-f4254ff7b34d.png)

# %% [markdown]
# - Lack of evidance inside the testing data.
# - Not proper utilize the statstical techniques inside the machine learning.
# - Poor data collection.
# - Poor hyperparamter tunning.
# - Poor selection of algorithm.

# %% [markdown]
# ![image.png](attachment:bccf177e-d986-420f-9508-1a0328358f17.png)

# %% [markdown]
# - Inside the machine learning we have to train the model on majority of the data for learning the pattern inside the data.
# - Meanwhile the remaing data we are going to feed inside the model in order to know whether our model is capable enough to get the prediction on the unseen data and for that purpose we need test data.
# - It gives us some information about the model is overfitted or underfitted.

# %% [markdown]
# ![image.png](attachment:4b573a12-4e3c-418c-80cb-4471bcb53ad7.png)

# %% [markdown]
# - A validation set is a set of data used to train artificial intelligence (AI) with the goal of finding and optimizing the best model to solve a given problem. Validation sets are also known as dev sets.
#
# - A supervised AI is trained on a corpus of training data. Training, tuning, model selection and testing are performed with three different datasets: the training set, the validation set and the testing set. Validation sets are used to select and tune the final AI model.
#
# - Training sets make up the majority of the total data, averaging 60 percent. In testing, the models are fit to parameters in a process that is known as adjusting weights.

# %% [markdown]
# ![image.png](attachment:c7e848ee-c8c7-421c-a56e-98446b1d3a8d.png)

# %% [markdown]
# - A validation set is a set of data used to train artificial intelligence (AI) with the goal of finding and optimizing the best model to solve a given problem. Validation sets are also known as dev sets.
#
# - A supervised AI is trained on a corpus of training data. Training, tuning, model selection and testing are performed with three different datasets: the training set, the validation set and the testing set. Validation sets are used to select and tune the final AI model.
#
# - Training sets make up the majority of the total data, averaging 60 percent. In testing, the models are fit to parameters in a process that is known as adjusting weights.
#
# - The validation set makes up about 20 percent of the bulk of data used. The validation set contrasts with training and test sets in that it is an intermediate phase used for choosing the best model and optimizing it. Validation is sometimes considered a part of the training phase. It is in this phase that parameter tuning occurs for optimizing the selected model. Overfitting is checked and avoided in the validation set to eliminate errors that can be caused for future predictions and observations if an analysis corresponds too precisely to a specific dataset.
#
# - Testing sets make up 20 percent of the bulk of the data. These sets are ideal data and results with which to verify correct operation of an AI. The test set is ensured to be the input data grouped together with verified correct outputs, generally by human verification. This ideal set is used to test results and assess the performance of the final model.
#
# - It is generally considered unwise to attempt further adjustment past the testing phase. Attempting to add further optimization outside the validation phase will likely to increase overfitting

# %% [markdown]
# ![image.png](attachment:41cf7fba-1ed7-45f1-9669-e330cebe2123.png)

# %% [markdown]
# - Data leakage will happen.
# - If you use this data to choose hyperparameters, you actually give the model a chance to "see" the test data and to develop a bias towards this test data. Therefore, you actually lose the possibility to find out how good your model would actually be on unseen data (because it has already seen the test data).
#  - lack of data,
#  - poor data quality,
#  - nonrepresentative data,
#  - uninformative features,
#  - excessively simple models that underfit the training data.
#  - complex models that overfit the data.
