# %% [markdown]
# ![image.png](attachment:efb51d69-a09e-48cd-8ab4-4726840d2b60.png)

# %% [markdown]
# - Data gathering
# - Data preprocessing
# - Exploratory data analysis (EDA)
# - Feature engineering
# - Training machine learning models of the following kinds:
#  - Regression
#  - Classification
#  - Clustering
# - Multivariate querying
# - Density estimation
# - Dimensionality reduction
# - Model / Algorithm selection
# - Testing and matching
# - Model monitoring
# - Model retraining

# %% [markdown]
# - Data preprocessing is a process of preparing the raw data and making it suitable for a machine learning model. It is the first and crucial step while creating a machine learning model.

# %% [markdown]
# - Getting the dataset
# - Importing libraries
# - Importing datasets
# - Finding Missing Data
# - Encoding Categorical Data
# - Splitting dataset into training and test set
# - Feature scaling
# - Feature Engineering

# %% [markdown]
# ![image.png](attachment:50d189b2-c28f-4a63-b398-7ba3f620fba8.png)

# %% [markdown]
# - Quantitative Data :- It is kind of data which is always avaliable in the form continous distribution.Its data types always in integer and float.Stastics Analysis harder.
# - Qualitive Data :- It is the kind of data which is always avaliable in the form descrete distribution.Its data types always in object,string,integer.Statstics Analysis easier.

# %% [markdown]
# ![image.png](attachment:ecd4870d-f813-479f-9a35-b314268bc13e.png)

# %%
import pandas as pd
data = pd.read_csv('../input/house-price-prediction/kc_house_data.csv')
data.head()

# %% [markdown]
# ![image.png](attachment:ccbe2997-d1a1-4b62-aa26-79789e3093d0.png)

# %% [markdown]
# - Poor Quality of Data
# - Underfitting of Training Data
# - Overfitting of Training Data
# - Machine Learning is a Complex Process
# - Lack of Training Data
# - Slow Implementation
# -  Imperfections in the Algorithm When Data Grows.

# %% [markdown]
# **Basic Remifications**

# %% [markdown]
# - **Model Complexity**
#
# - Model complexity is nothing but building a simple model with fewer parameters. This method is less susceptible to over-fitting. Example: Naive Bayes, Linear Regression.
# - Using Ensemble learning technique: It is defined as several learners are combined to obtain a better performance than any individual learners. It is often used to improve classification and prediction.
#
# - **Transfer Learning**
#
# - Transfer Learning is used in the case of Deep Learning and Neural Networks. It uses a pre-built model, which is then tweaked on the small dataset that you have.
# - It is also defined as the practice of reusing a trained Neural Networks, that solve a similar problem to yours, usually leaving the network architecture unchanged and reusing some of the model weights.
# - It is very much useful when the new dataset is small and not sufficient to train the model from scratch.
#
# - **Data Augmentation**
#
#  - Data Augmentation helps to tweak (make slight improvements) to get new images.It takes the pre-existing samples and changes them in some way to create new samples and also increase the number of training samples and typically used with Image data.
# - Disturb images in some way to generate new images, such as,Scaling,Rotation,Affine Transforms
# - These image processing options are often used as pre-processing techniques to make image classification models built using CNN are robust.
#
# - **Synthetic Data**
#
# - Synthetic
#  - data generally refers to artificially generating samples which mimic the real-world data (it is one only if we have a good understanding of features). This may induce bias in existing data.

# %% [markdown]
# ![image.png](attachment:3fc2c2ec-7d77-421f-a8f9-bb2e8426131b.png)

# %% [markdown]
# - Unique value count
# - Frequency Count
# -  Pareto Analysis
# - Histogram
# - Cramer-V correlation between all Categorical columns.
# - Correlation between two specific categorical columns.
# - Clustering or Segmentation.
# - Outlier overview
# -  Outlier analysis for multiple columns
# - Specialised Visualisation.

# %% [markdown]
# ![image.png](attachment:a18f1a0f-4b54-4aca-801b-2d72673d7b68.png)

# %% [markdown]
# - In the presence of missing value in any variable become very uncertain for us to filling that values.
# - It might be miss-lead us in terms of prediction due improper filling of the values.
# - We can get the bised and overfit model.
# - It can not give good result once it will deploy on cloud and feed with unseen data.

# %% [markdown]
# **What can be done about it ?**
#
# - If we have more than 50% of the missing values then it advisable to remove that colums because it can misslead us in terms of prediction.
# - If we have 20% missing value or lesser missing values then we can fill that values with below way.
#  - If that value is continous then we have use mean and median for right skewed data and left skewed data respectively.
#  - If we are not able to get the desirable smooth curve then we use the `kkn-imputer` so that we can able to get the nearest values while filling the missing values.
#  - In time series data analysis,we have ffill methods to get the filling of data from its last values because time series is dependent on the last values of it.
#  - While filling categorcal data,we are going to fill it with mode of that categorical data.

# %% [markdown]
# ![image.png](attachment:dd977317-3c0f-4da1-bf71-7da393711c59.png)

# %% [markdown]
# **Methods For Deaing with Missing Values**
#
# - fill method.
# - bfill method
# - ffill method
# - knn_imputer
# - SimpleImputer
# - Iterative Imputer

# %% [markdown]
# ![image.png](attachment:6e055891-7425-43fc-8cf6-d1f3c58cfb64.png)

# %% [markdown]
# **Data Pre-Processing Techniques**
#
# - data cleaning
# - Data Scalling
# - Outliers Handling.
# - Feature encoder.
# - OneHotEncoding
# - Feature Engineering with the help ANNOVA and chi2 Test.
# - EDA
# - Data Visualization.

# %% [markdown]
# **Dimensionality Reduction Techniques**
#
# - When we have more number of colums,there is chances of getting duplicate columns as well as there is chances of getting columns which are not so much correlated the target variables.
# - As the number of columns increase the predictive ability of model will get decreases.
# - That is going called Curse Of Dimensionality.
# - Once the less correlated or meanless data we have removed the model will get confused and give us proper prediction.
# - That is why we need dimensionality reduction technique.
# - In the dimensionality reduction technique that is PCA,algorithm is going to look for variance with respect to the various hyperplan.
# - 1st plan of PCA,we will get the higher Variance and remaining variance will cover with 2nd hyper-plan.
# - These plans are called orthogonal plan.
# - As the PCA get increase the information and important of that also getting decrease.e.g. 1st plan contains higher information means highly important feature.

# %% [markdown]
# ![image.png](attachment:4d93f7f4-5193-4fc4-b898-c7d124644ae8.png)

# %% [markdown]
# - The Interquartile range formula helps in finding the difference between the third quartile and the first quartile. The Interquartile range formula measures the variability, based on dividing an ordered set of data into quartiles. Quartiles are three values or cuts that divide each respective part as the first, second, and third quartiles, denoted by Q1, Q2, and Q3, respectively.
# - Q1 is the cut in the first half of the rank-ordered data set, Q2 is the median value of the set, Q3 is the cut in the second half of the rank-ordered data set.
# - The Interquartile Range (IQR) formula is a measure of the middle 50% of a data set. The smallest of all the measures of dispersion in statistics is called the Interquartile Range. The difference between the upper and lower quartile is known as the interquartile range.

# %% [markdown]
# ![image.png](attachment:2ea570de-f1ce-4541-a0af-285ef8f96621.png)

# %% [markdown]
# **BoxPlot**

# %% [markdown]
# ![image.png](attachment:11557898-dcf3-4c0c-8269-56c298bb7150.png)

# %% [markdown]
# - The image above is a boxplot. A boxplot is a standardized way of displaying the distribution of data based on a five number summary `(“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”)`. It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.
# - A boxplot is a graph that gives you a good indication of how the values in the data are spread out. Although boxplots may seem primitive in comparison to a histogram or density plot, they have the advantage of taking up less space, which is useful when comparing distributions between many groups or datasets.

# %% [markdown]
# ![image.png](attachment:346d3b37-764c-4820-a2a1-ec3d541d8609.png)

# %% [markdown]
# ![image.png](attachment:05c0919e-30d5-4ada-81ab-b01e10a38fe1.png)

# %% [markdown]
# **The gap between the quartiles**
# - In a set of data, the quartiles are the values that divide the data into four equal parts. The median of a set of data separates the set in half.

# %% [markdown]
# ![image.png](attachment:edcebceb-401b-444e-ac3f-02cb4ce9aa0d.png)

# %% [markdown]
# - The median of the lower half of a set of data is the `lower quartile ( LQ ) or Q1 .`
#
# - The median of the upper half of a set of data is the `upper quartile ( UQ ) or Q3 .`
#
# - The upper and lower quartiles can be used to find another measure of variation call the interquartile range .
#
# - The interquartile range or IQR is the range of the middle half of a set of data. It is the difference between the upper quartile and the lower quartile.
#
# - `Interquartile range = Q3−Q1`
#
# - In the above example, the lower quartile is 52 and the upper quartile is 58 .
#
# - The interquartile range is `58−52 or 6 .`
#
# - Data that is more than 1.5 times the value of the interquartile range beyond the quartiles are called outliers .
#
# - Statisticians sometimes also use the terms semi-interquartile range and mid-quartile range .

# %% [markdown]
# ![image.png](attachment:737b2493-d42d-428c-bff6-39c3998b9b91.png)

# %% [markdown]
# **Use Of Cross-Tab**

# %% [markdown]
# - crosstab. Compute a simple cross tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed.

# %%
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset('titanic')
bins =[0,10,70]
titanic['adult']= pd.cut(titanic.age,bins,labels =['kid','adult'])
pd.crosstab(titanic.survived,titanic.adult,normalize=True,margins=True)
