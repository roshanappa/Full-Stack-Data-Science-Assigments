# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RGBA :- It stands for RED,GREEN,BLUE and Alpha Color.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image
img = Image.open('bsbs.png')
rgba = img.convert('RGBA')
color =rgba.getpixel((200,300))
print(color)  #these are values of RGBA at the x = 200 and y = 300 cordinate.
# Out:
# (255, 255, 255, 255)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Inside the PIL package we have attribute called as box it work whenever we are going to crop image.
# - A4-tuple defining the left, upper, right, and lower pixel coordinate.
# - and returns the Image (Returns a rectangular region as (left, upper, right, lower)-tuple).

# %%
from PIL import Image
img = Image.open('bsbs.png')
test_img = img.crop(box=(2,0.5,120,40))
test_img.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image
img = Image.open('bsbs.png')
width,height = img.size
print('Width :-',width)
print('Height:-',height)
# Out:
# Width :- 533
# Height:- 445

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
image = Image.open('bsbs.png')
new_image = image.resize((100, 100))
new_image.save('image_400.png')
width,height=new_image.size
print('width :-',width)
print('height :-',height)
# Out:
# width :- 100
# height :- 100

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
image = Image.open('bsbs.png')
new_image = image.resize((100, 100))
new_image.save('image_400.png')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image,ImageDraw
im = Image.new('RGB', (500, 300), (128, 128, 128))
draw = ImageDraw.Draw(im)
draw

# %%
draw.ellipse((100, 100, 150, 200), fill=(255, 0, 0), outline=(0, 0, 0))
draw.rectangle((200, 100, 300, 200), fill=(0, 192, 192), outline=(255, 255, 255))
draw.line((350, 200, 450, 100), fill=(255, 255, 0), width=10)

im.save('pillow_imagedraw.jpg', quality=95)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image,ImageDraw
im = Image.new('RGB', (500, 300), (128, 128, 128))
draw = ImageDraw.Draw(im)
draw

# %%
draw.ellipse((100, 100, 150, 200), fill=(255, 0, 0), outline=(0, 0, 0))
draw.rectangle((200, 100, 300, 200), fill=(0, 192, 192), outline=(255, 255, 255))
draw.line((350, 200, 450, 100), fill=(255, 255, 0), width=10)
im.show()

# %%
im = Image.open('bsbs.png')
draw = ImageDraw.Draw(im)

draw.pieslice((15, 50, 140, 175), start=30, end=330, fill=(255, 255, 0))
im.show()

# %% [markdown]
# ## Thanks !!!
