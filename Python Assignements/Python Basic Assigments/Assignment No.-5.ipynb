# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
a = dict()

# %%
type(a)
# Out:
# dict

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a={"foo":42}

# %%
print(a.values())
# Out:
# dict_values([42])

# %%
print(a.keys())
# Out:
# dict_keys(['foo'])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dictionary always stored the data in key and value format whereas the list stored data in value format only.List data struture is square bracket and dictionary has curley bracket and inside that we have provide colon for distinguish the key and value inside the dictionary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
spam = {'bar':100}

# %%
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-9b5a94d1de8d> in <module>
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# we will get the key error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If the disctionary is stored in spam variable then,

# %% [markdown]
# ### "Cat" In Spam

# %% [markdown]
# "Cat" is the string data type is avalible inside the spam variable but not speciffied wheather it is value or key.

# %% [markdown]
# ### "Cat" in Spam.key()

# %% [markdown]
# "Cat" in spam.key() means it is string data type avalible inside the dictionary in form of key of that particular dictionary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If the disctionary is stored in spam variable then,

# %% [markdown]
# ### "Cat" In Spam

# %% [markdown]
# "Cat" is the string data type is avalible inside the spam variable but not speciffied wheather it is value or key.

# %% [markdown]
# ### "Cat" in Spam.values()

# %% [markdown]
# "Cat" in spam.values() means it is string data type avalible inside the dictionary in form of vlues which will be associate with any key paramter of that particular dictionary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
spam ={}

spam.setdefault('color','black')
# Out:
# 'black'

# %%
spam
# Out:
# {'color': 'black'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pprint.pprint(spam)
# Out:
# {'color': 'black'}

# %% [markdown]
# ## Thank you !!
