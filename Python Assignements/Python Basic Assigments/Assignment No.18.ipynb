# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from zoo import hours

# %%
hours()
# Out:
# 'Open 9-5 daily'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import zoo as menagerie

# %%
menagerie.hours()
# Out:
# 'Open 9-5 daily'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from zoo import hours
hours()
# Out:
# 'Open 9-5 daily'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from zoo import hours as info
info()
# Out:
# 'Open 9-5 daily'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
paris = {'a':1,'b':2,'c':3}
paris
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
OrderDict = {'a':1,'b':2,'c':3,'fancy':5}

# %%
OrderDict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'fancy': 5}

# %% [markdown]
# Yes,it is following the same order as plain.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict_of_lists ={}

dict_of_lists['a']='something for a'

# %%
print(dict_of_lists['a'])
# Out:
# something for a

# %% [markdown]
# ### Thanks !!
