# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Functions are important for make program very dymanic,reusable and helps write code in effiencient way.
# - If we want do one operation again and again you can make function and use whenver we required as well as we can call that function in other module of python as well with writting codes that is how it is very code efficient.
# - Program will in organized way if we use the modular programming.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Whenever we call function and inside we have provide the approprite attributes which are required after that it does work on the whatever the operation we have written inside function and thier output will be return by using return keyword.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There is keyword that is **`def`** after that keyword we have write the name of function and use opened ended and closed ended round bracket inside that we have provide attribute which majority used in below block and then use semicolon and then perform certain operation and output based what we want to return.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Function can be inbuit or custom we can both whenver we use it we need to call it first.
# - Function is the mothing but the a program which is made for certain operation which is going to use so many time.
# - But After creating the function we also have to call it so that we execute that function for performing the certain operation which is given inside the funcion.
#
# - Calling has to done outside the function not the inside the function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the python program we have local variable and global variable are avalible and they have their own scopes that is depends on calling.
#
# If we have global variable then it always above the class and local variable is always inside the method that class.
#
# If we call the method will return their own variable but inspite of the global automatically call so from that we can say gloabal variable excute always be there when run the program but execution starts from the local variable then goes to gloabal variable.
#
# If we wanted to execute the Global inside the function or method then we have to define it by using the keyword `global` and if we have more one global variable in that case we have use `globals` and we can change variable name.
#
#
# -  The variable is first searched in Local, followed by Enclosed, then global and finally built-in.
# - The Namespaces are searched for scope resolution according to the LEGB rule. The LEGB stands for :L: Local, E: Enclosed, G: Global, B: Built-in. The sequence of LEGB is important. The variable is first searched in Local, followed by Enclosed, then global and finally built-in.
#
# - From the below way we can say that local has four scope and global only one scope
#
# - Execution always start from the Local to Global.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Always we called the function excution always start from the local varible so variable inside method getting involve in operation according to the whichever code we have written inside the function.
#
# As soon as we call function and insert attribute iniside the function while calling and according to the scope it will start first execution from local variable and start overriding the attriutes with user given attribute to defined attributes and gives us the return the opration result which we want.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As we define a function and inside body of the function we have write the code which will perform opeartion based on required result and when try to display that result by calling function it doesn't work untile and unless we will not gonna use the return keywork along with return value or varible.
#
# return also called as task ending keyword.
#
# It is possible to write the return in expression format but it has be a part of varible and we are going to use and espeically mathematically,logical expression does work.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For making function of local variable to globle we have to use keyword inside the function that is nothing but `global` and if we want to change that function values then we can use `globals` and change that values when we have multiple varibals as global variable.

# %% [markdown]
# By doing this global variable get the access or scope inside the function as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# None is the kind data type which is not containing any data type.None is a data type of its own (NoneType) and only None can be None.

# %% [markdown]
# If see here

# %%
a1 = print(10) #In this print always return the null data type
# Out:
# 10

# %%
type(a1)
# Out:
# NoneType

# %%
a = 10
print(10)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sorry,It does contains PyPI python libaray

# %%
import areallyournamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-35e1dc121b6e> in <module>
# ----> 1 import areallyournamederic
#
# ModuleNotFoundError: No module named 'areallyournamederic'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - After importting spam module I will call the method bacon()
#
# - by using the below way
#
# -`spam.bacon()`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# First if I will be using the Jupyter Notebook then I restart kernel If we will using the pycharm kind of IDE then use Try and except methodology otherwise raise an exeception each and every function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Try keyword is help to execute the existing code and except clause allow the raise expections or error and shows us if any kind error it found without stopping an execution of exsiting runing code.
#
# Try block always contains the code which is going to run and any user press wrong input then it will throw the error but to prevent that situation we have any option that os except cluase.It does take care of it message us that we mistake we have done with stoping the code execution.

# %% [markdown]
# ## Thank You !!
