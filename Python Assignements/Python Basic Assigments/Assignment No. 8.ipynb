# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Yes,the python Standard lncluded the **`PyInputPlus`**

# %%
# !pip install PyInputPlus
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Because for allias purpose.

# %%
import pyinputplus as pyip

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result1 = pyip.inputInt()
# Out:
# 44

# %%
result2 = pyip.inputFloat()
# Out:
# 55.66

# %%
result3 = pyip.inputInt()
# Out:
# 88.9
# '88.9' is not an integer.
# 8

# %%
result4 = pyip.inputFloat()
# Out:
# 66

# %% [markdown]
# In the method of **`inputint`** we have suppose to use interger values and it will automatically identify that it is the interger,but if we enter or given input the float number then the it will accept it shows us an issue with that input number.
#
# In the case of **`inputFloat`** we have suppose to use the float number or decimal number and it automatically identify that,but if we enter whole instead of float even it is not going to throw an error,it is accepting it and display the result as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result = pyip.inputInt(min=0,max=99)
# Out:
# 100
# Number must be at maximum 99.
# -1
# Number must be at minimum 0.
# 77

# %% [markdown]
# The above way we can do that.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

# %%
result = pyip.inputStr('Your Favorite animal ',blockRegexes=['Cat'])
# Out:
# Your Favorite animal Cat
# This response is invalid.
# Your Favorite animal Cow

# %%
result = pyip.inputStr('Your Favorite animal ',allowRegexes=['Cat'])
# Out:
# Your Favorite animal Cat

# %%
result = pyip.inputStr('Your Favorite animal ',allowRegexes=['Cat'])
# Out:
# Your Favorite animal Cow

# %% [markdown]
# - From the above we can say that input word is going update inside our substring while we choose keyword that we had not mentioned inside the **`blockregexes`** list and vice versa.
# - In the case of **`allowRegexes`** if we can choose the any word in order to complete our given substring,whether that word is avaliable inside in our allowRegexes keyword or not.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result = pyip.inputStr(limit=3)
# Out:
# Blank values are not allowed.
#
# Blank values are not allowed.
#
# Blank values are not allowed.
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# F:\anaconda\lib\site-packages\pyinputplus\__init__.py in _genericInput(prompt, default, timeout, limit, applyFunc, validationFunc, postValidateApplyFunc, passwordMask)
#     166         try:
# --> 167             possibleNewUserInput = validationFunc(
#     168                 userInput
#
# F:\anaconda\lib\site-packages\pyinputplus\__init__.py in <lambda>(value)
#     242
# --> 243     validationFunc = lambda value: pysv._prevalidationCheck(
#     244         value, blank=blank, strip=strip, allowRegexes=allowRegexes, blockRegexes=blockRegexes, excMsg=None,
#
# F:\anaconda\lib\site-packages\pysimplevalidate\__init__.py in _prevalidationCheck(value, blank, strip, allowRegexes, blockRegexes, excMsg)
# ...

# %% [markdown]
# It throws an error i.e. **`RetryLimitException`**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result = pyip.inputStr(limit=3,default='hello')
# Out:
# Blank values are not allowed.
#
# Blank values are not allowed.
#
# Blank values are not allowed.

# %% [markdown]
# It is giving us warnings and at the end if we do not enter the number at the end we will get the error.

# %%
result
# Out:
# 'hello'

# %% [markdown]
# **And whichever the variable we have consider in order to store the information it gives an return string we had in default attribute.**

# %% [markdown]
# ## Thanks !!
