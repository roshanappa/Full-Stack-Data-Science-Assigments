# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In Python strings, the backslash `"\"` is a special character, also called the "escape" character.

# %% [markdown]
# It is used in representing certain whitespace characters

# %% [markdown]
# `"\t" `is a tab, `"\n"` is a newline, and `"\r"` is a carriage return. Conversely, prefixing a special character with `"\" `turns it into an ordinary character.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# n escape charecters is use for new line creation and t is stand for tab seperated charecter.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Roshan\nAppa")  #new line charecter
# Out:
# Roshan
# Appa

# %%
print("Roshan\tAppa")  #tab seperated charecter
# Out:
# Roshan	Appa

# %%
carriage_return = "I am going to \rSchool."

print(carriage_return)
# Out:
# School.

# %% [markdown]
# In the case carage return sentence from School and school has length 5 so its overrride five index position at begining of the setence and after whatever the sentence it will print.

# %% [markdown]
# Here in our example start from School and after that it takes start after fifth index position of original string and ends upto escape charecter that is `"\r"`.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
string = "Howl's Moving Castle"

# %% [markdown]
#  Because we have used the double in order to create the string and in that double quote string we can using single quote in order represent the string.
#
# Instead of double quote if we will single quote then it will not complete required string that we want.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
string = 'I am working in Nagpur as,'+ os.linesep + 'Data Analyst. '
print(string)
# Out:
# I am working in Nagpur as,
# Data Analyst.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'hello,world!'[1]
# Out:
# 'e'

# %%
'hello,world!'[0:5]
# Out:
# 'hello'

# %%
'hello,world!'[:5]
# Out:
# 'hello'

# %%
'hello,world!'[3:]
# Out:
# 'lo,world!'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'Remember,remember,the fith of July'
# Out:
# 'Remember,remember,the fith of July'

# %%
'Remember,remember,the fith of July'.split()
# Out:
# ['Remember,remember,the', 'fith', 'of', 'July']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **.center()**
# - **.lstrip()**
# - **.rstrip()**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **lstrip() :-** This is for left hand side white space removal method in string
# - **rstrip() :-** This is for right hand side white space removal method in string
# - **strip() :-**  This is for start or end whitespace will there it will remove.

# %%
sring = 'Roshan not only good boy but also   '

# %%
ring = '    Roshan not only good boy but also'

# %%
sring.strip()
# Out:
# 'Roshan not only good boy but also'

# %%
ring.strip() #It can remove both end whitespaces.
# Out:
# 'Roshan not only good boy but also'

# %%
sring.rstrip() #help us to remove Right hand side whitespace
# Out:
# 'Roshan not only good boy but also'

# %%
ring.lstrip() #help us to remove left hand side whitespace
# Out:
# 'Roshan not only good boy but also'

# %% [markdown]
# ## Thank You !!
